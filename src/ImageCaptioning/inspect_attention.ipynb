# %%
# %load_ext autoreload
# %autoreload 2


import torch
import torchvision

import cv2
import PIL.Image

import numpy as np
import matplotlib.pyplot as plt
import textwrap
import os

from data.DownloadData import load_meta
from data.LoadData import ImageCaptionDataset
from data.LoadData import String2Int
from models import ShowAttendTell
from utils import VizAttention


#http://proceedings.mlr.press/v37/xuc15.pdf
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train_meta = load_meta("./data/metadata/train_meta.json")
valid_meta = load_meta('./data/metadata/valid_meta.json')

train_paths = ['./data'+path for path in train_meta['paths']]
valid_paths = ['./data'+path for path in valid_meta['paths']]

# %%
fig, axes = plt.subplots(2, 4, figsize=(20,5))

for i, ax in enumerate(axes.flat):
    img = cv2.imread(train_paths[i])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    ax.imshow(img)
    ax.set_title('\n'.join(textwrap.wrap(train_meta['labels'][i], width=25)))
    ax.axis('off')
fig.suptitle("**Training Examples**")
fig.tight_layout()

# %%
remove_punct = '<>'
start_token = '<sos>'
stop_token = '<eos>'
pad_token = '<pad>'

stoi_config = String2Int(train_meta['labels']+valid_meta['labels'],
                        start_token=start_token, stop_token=stop_token, pad_token=pad_token,
                        remove_punct=remove_punct
)

vocab_size = len(stoi_config)
longest_caption = len(max([line.split() for line in train_meta['labels']], key=len))
print(f"{vocab_size = }")
print(f"{longest_caption = }")



train_dataset = ImageCaptionDataset(X_paths=train_paths,
                                    y_labels=train_meta['labels'],
                                    string2int=stoi_config)

valid_dataset = ImageCaptionDataset(X_paths=valid_paths, 
                                    y_labels=valid_meta['labels'],
                                    string2int=stoi_config)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=12, shuffle=False, drop_last=True) #shuffle to True to reshuffle the data at every epoch

x, y = next(iter(train_dataloader))
print(f"{x.shape = }")
print(f"{y.shape = }")
# Out:
# vocab_size = 4248
# longest_caption = 41
# x.shape = torch.Size([12, 3, 256, 256])
# y.shape = torch.Size([12, 43])

# %%
# %autoreload 2

encoder = ShowAttendTell.Encoder()
decoder = ShowAttendTell.Decoder(embed_dim=11, dec_hidden_dim=64, attention_dim=50, string2int=stoi_config)


encoder_out = encoder(x)
encoder_out = encoder_out.view(12, -1, 2048)
predictions, alphas, decode_len = decoder(encoder_out, y)

# %%
alphas[0][0].shape ##alphas are shape (batch_size, max_caption_length_in_that_batch, num_pixels_in_encoded_image)
##alphas[0][0] would get the attention scores for the first word (for the first sample in the batch)
# Out:
# torch.Size([196])

# %%
sample = 0
plt.figure(figsize=(30,20))
VizAttention.plot(x[sample], label=y[sample], alphas=alphas[sample].detach(), string2int=stoi_config, smooth=True)

# %%
alphas[1].shape
# Out:
# torch.Size([18, 196])

# %%
y[1]
# Out:
# tensor([   0, 3375, 2236, 3640, 1952, 3807, 3863,  200, 3807, 3420, 4145, 2710,
#         4186, 2714,  277, 3786, 1562, 3987,    1,    2,    2,    2,    2,    2,
#            2,    2,    2,    2,    2,    2,    2,    2,    2,    2,    2,    2,
#            2,    2,    2,    2,    2,    2,    2])

# %%
alphas[1].shape
# Out:
# torch.Size([18, 196])

# %%
sample = 1
plt.figure(figsize=(30,20))
VizAttention.plot(x[sample], label=y[sample], alphas=alphas[sample].detach(), string2int=stoi_config, smooth=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [91], line 3
#       1 sample = 1
#       2 plt.figure(figsize=(30,20))
# ----> 3 VizAttention.plot(x[sample], label=y[sample], alphas=alphas[sample].detach(), string2int=stoi_config, smooth=True)
#
# File c:\Users\hanse\Documents\ml_code\dl-replications\image_captioning\utils\VizAttention.py:38, in plot(image, label, alphas, string2int, smooth, im_size)
#      34 plt.imshow((image*255).astype('uint8'))
#      37 if smooth:
# ---> 38     alpha = skimage.transform.pyramid_expand(alphas[t, :].numpy().reshape(14,14), upscale=24, sigma=8)
#      39 else:
#      40     alpha = skimage.transform.resize(alphas[t, :].numpy(), [im_size*24, im_size*24])
#
# IndexError: index 18 is out of bounds for dimension 0 with size 18
